# %%
import pandas as pd

# %%
data = pd.read_csv("sales.csv")

# %%
data.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16.46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16.48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13.33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13.38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15.31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
data['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
data['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
data.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12.35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
data.iloc[200:210]
# Out:
#      Invoice ID        Date   Time  Gender     Location     City Member  \
# 200   576523018   2/15/2018  12.35    Male  Water tower  Chicago     No
# 201   414119922   1/30/2018  11.07    Male  Water tower  Chicago     No
# 202   123247697  02-08-2018  20.03    Male   Brookfield  NewYork     No
# 203    40419058   1/26/2018  14.53    Male  Water tower  Chicago    Yes
# 204   890497298   2/25/2018  18.06  Female  Water tower  Chicago     No
# 205   885702268   1/28/2018  12.45    Male   Brookfield  NewYork     No
# 206   172252194   3/22/2018  20.10  Female    Park lane   Dallas     No
# 207   866140211   2/25/2018  13.34  Female    Park lane   Dallas     No
# 208   597678548   3/15/2018  17.35    Male  Water tower  Chicago    Yes
# 209   428818456   2/25/2018  18.50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# ...

# %%
data.tail()
# Out:
#      Invoice ID        Date   Time  Gender     Location     City Member  \
# 995   818829599   3/26/2018  11.19    Male    Park lane   Dallas     No
# 996   556589713   2/20/2018  17.17    Male  Water tower  Chicago    Yes
# 997    82324424  02-06-2018  11.44    Male   Brookfield  NewYork     No
# 998   783661702   1/29/2018  15.44  Female   Brookfield  NewYork     No
# 999   759171975   1/31/2018  10.13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3

# %%
data[data['Gender'] == 'Male']
# Out:
#      Invoice ID        Date   Time Gender     Location     City Member  \
# 0     460489604   1/25/2018  16.46   Male   Brookfield  NewYork    Yes
# 2     411909258   2/25/2018  13.33   Male  Water tower  Chicago     No
# 5     263634050  03-09-2018  17.55   Male   Brookfield  NewYork    Yes
# 6      99646662  03-04-2018  13.21   Male  Water tower  Chicago     No
# 7     188869875  03-08-2018  13.24   Male    Park lane   Dallas     No
# ..          ...         ...    ...    ...          ...      ...    ...
# 992   927909627  03-02-2018  13.35   Male   Brookfield  NewYork     No
# 994   446582560   1/31/2018  19.00   Male  Water tower  Chicago     No
# 995   818829599   3/26/2018  11.19   Male    Park lane   Dallas     No
# 996   556589713   2/20/2018  17.17   Male  Water tower  Chicago    Yes
# 997    82324424  02-06-2018  11.44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data[data['Gender'] == 'Female'].head()
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16.48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13.38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15.31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16.05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11.32  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 3    Sporting     89         4    356    Gpay       1
# 4       Books     82         5    410    Cash       4
# 9       Books     80         2    160    Cash       4
# 10  Furniture     35         4    140    Gpay       4

# %%
data[data['City'] == 'NewYork']
# Out:
#      Invoice ID        Date   Time  Gender    Location     City Member  \
# 0     460489604   1/25/2018  16.46    Male  Brookfield  NewYork    Yes
# 5     263634050  03-09-2018  17.55    Male  Brookfield  NewYork    Yes
# 10    388412668   2/26/2018  11.32  Female  Brookfield  NewYork     No
# 14    547572603   3/21/2018  13.23  Female  Brookfield  NewYork     No
# 15    355981315   2/15/2018  15.47  Female  Brookfield  NewYork    Yes
# ..          ...         ...    ...     ...         ...      ...    ...
# 991   699906043   2/15/2018  12.58    Male  Brookfield  NewYork    Yes
# 992   927909627  03-02-2018  13.35    Male  Brookfield  NewYork     No
# 993   455112063   3/19/2018  17.30  Female  Brookfield  NewYork    Yes
# 997    82324424  02-06-2018  11.44    Male  Brookfield  NewYork     No
# 998   783661702   1/29/2018  15.44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
data.iloc[100:201]
# Out:
#      Invoice ID        Date   Time  Gender     Location     City Member  \
# 100   515862366  02-12-2018  10.57  Female    Park lane   Dallas     No
# 101    42787009   3/28/2018  11.25  Female    Park lane   Dallas    Yes
# 102   780195692   2/20/2018  12.42  Female    Park lane   Dallas     No
# 103   881639873   2/27/2018  15.05    Male    Park lane   Dallas    Yes
# 104   443388850  02-05-2018  16.31    Male   Brookfield  NewYork    Yes
# ..          ...         ...    ...     ...          ...      ...    ...
# 196   925499362  01-12-2018  11.22  Female   Brookfield  NewYork    Yes
# 197   579316236  03-01-2018  13.44  Female  Water tower  Chicago    Yes
# 198   445531158  02-09-2018  20.19  Female    Park lane   Dallas     No
# 199   805526095   3/27/2018  18.00    Male    Park lane   Dallas    Yes
# 200   576523018   2/15/2018  12.35    Male  Water tower  Chicago     No
#
#       Category  Price  Quantity  Total Payment  Rating
# ...

# %%
data.sum()['Total']
# Out:
# 207788

# %%
data.max()
# Out:
# Invoice ID      999665753
# Date            3/30/2018
# Time                20.59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
data[data['Total'] == data.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19.45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13.21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
data[data['Total'] == data.min()['Total']]
# Out:
#      Invoice ID        Date   Time  Gender   Location    City Member  \
# 184   801334050   1/21/2018  20.18  Female  Park lane  Dallas     No
# 587   646176653  03-10-2018  19.39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
data.groupby('City').sum()
# Out:
#            Invoice ID     Time  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  4963.00  16152      1307  65215    1023
# Dallas   160721744770  5092.35  17289      1344  70432    1003
# NewYork  169526550245  5155.63  17671      1408  72141     946

# %%
data.groupby('Gender').sum()['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
data.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
# whic location has highest and lowest sales 
# represent sales on a barchart, also show the market share for each location

# %%
location_list = data.groupby('Location')

# %%
location = [a for a,b in location_list]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
s = data.groupby('Location').sum()['Total']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location,s)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(data.groupby('location').sum()['Total'],labels=Location	)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13784\3237365993.py in <module>
# ----> 1 plt.pie(data.groupby('location').sum()['Total'],labels=Location )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
#     881
# ...

# %%
data.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16.46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16.48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13.33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13.38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15.31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
# Which location has more female customers
# Which customers has more male customers

# %%
location_sale = data.groupby(['Gender','Location']).count()['Invoice ID']

# %%
unstack_sale = location_sale.unstack(level=0)

# %%
unstack_sale.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>
